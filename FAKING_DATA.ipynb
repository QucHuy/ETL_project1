# %%
from cassandra.cluster import Cluster
from cassandra.cqlengine import columns
from cassandra.cqlengine.models import  Model
from cassandra.cqlengine.management import sync_table
from cassandra.cqlengine import connection
from cassandra.query import dict_factory
from datetime import datetime, timedelta
import time
import cassandra
import random
import uuid
import math
import pandas as pd
pd.set_option("display.max_rows", None, "display.max_columns", None)
import datetime
from sqlalchemy import create_engine
import pandas as pd
import numpy as np
import mysql.connector

# %%
host = 'localhost'
port = '3306'
db_name = 'Data_Warehouse'
user = 'root'
password = 'mysql'
url = 'jdbc:mysql://' + host + ':' + port + '/' + db_name
driver = "com.mysql.cj.jdbc.Driver"

# %%
keyspace = 'data_engineering'
cassandra_login = 'cassandra'
cassandra_password = 'cassandra'
cluster = Cluster()
session = cluster.connect(keyspace)

# %%
def get_data_from_job(user,password,host,database):
    cnx = mysql.connector.connect(user=user, password=password,
                                         host=host,
                                      database=database)
    query = """select id as job_id,campaign_id , group_id , company_id from job"""
    mysql_data = pd.read_sql(query,cnx)
    return mysql_data

# %%
def get_data_from_publisher(user,password,host,database):
    cnx = mysql.connector.connect(user=user, password=password,
                                         host=host,
                                      database=database)
    query = """select distinct(id) as publisher_id from master_publisher"""
    mysql_data = pd.read_sql(query,cnx)
    return mysql_data

# %%
def generating_dummy_data(n_records,session,user,password,host,db_name):
    publisher = get_data_from_publisher(user,password,host,db_name)
    publisher = publisher['publisher_id'].to_list()
    jobs_data = get_data_from_job(user,password,host,db_name)
    job_list = jobs_data['job_id'].to_list()
    campaign_list = jobs_data['campaign_id'].to_list()
    company_list = jobs_data['company_id'].to_list()
    group_list = jobs_data[jobs_data['group_id'].notnull()]['group_id'].astype(int).to_list()
    i = 0 
    fake_records = n_records
    while i <= fake_records:
        create_time = str(cassandra.util.uuid_from_time(datetime.datetime.now()))
        bid = random.randint(0,1)
        interact = ['click','conversion','qualified','unqualified']
        custom_track = random.choices(interact,weights=(70,10,10,10))[0]
        job_id = random.choice(job_list)
        publisher_id = random.choice(publisher)
        group_id = random.choice(group_list)
        campaign_id = random.choice(campaign_list)
        ts = datetime.datetime.now().strftime('%Y-%m-%d %H:%M:%S')
        sql = """ INSERT INTO tracking (create_time,bid,campaign_id,custom_track,group_id,job_id,publisher_id,ts) VALUES ('{}',{},{},'{}',{},{},{},'{}')""".format(create_time,bid,campaign_id,custom_track,group_id,job_id,publisher_id,ts)
        print(sql)
        session.execute(sql)
        i+=1 
    return print("Data Generated Successfully")

# %%
status = "ON"
while status == "ON":
    generating_dummy_data(n_records = random.randint(1,20),session = session , user = user , password = password , host = host , db_name = db_name )
    time.sleep(10)
# Out:
#  INSERT INTO tracking (create_time,bid,campaign_id,custom_track,group_id,job_id,publisher_id,ts) VALUES ('91ffdb72-45c2-11ee-944d-588f7663d07d',0,57,'click',10,810,9,'2023-08-28 16:47:27')
#  INSERT INTO tracking (create_time,bid,campaign_id,custom_track,group_id,job_id,publisher_id,ts) VALUES ('9203d362-45c2-11ee-878c-d07b3bb7f058',1,132,'click',10,1574,13,'2023-08-28 16:47:27')
#  INSERT INTO tracking (create_time,bid,campaign_id,custom_track,group_id,job_id,publisher_id,ts) VALUES ('920607ae-45c2-11ee-a989-db254853c4ee',0,221,'click',41,503,16,'2023-08-28 16:47:27')
#  INSERT INTO tracking (create_time,bid,campaign_id,custom_track,group_id,job_id,publisher_id,ts) VALUES ('9208656c-45c2-11ee-bba6-20cda4107114',1,13,'conversion',19,1383,32,'2023-08-28 16:47:27')
#  INSERT INTO tracking (create_time,bid,campaign_id,custom_track,group_id,job_id,publisher_id,ts) VALUES ('920a6ad8-45c2-11ee-9bba-121ad5a6245c',0,1,'unqualified',35,130,11,'2023-08-28 16:47:27')
#  INSERT INTO tracking (create_time,bid,campaign_id,custom_track,group_id,job_id,publisher_id,ts) VALUES ('920c8d0e-45c2-11ee-ad31-46b029874c43',1,61,'click',41,1758,1,'2023-08-28 16:47:27')
#  INSERT INTO tracking (create_time,bid,campaign_id,custom_track,group_id,job_id,publisher_id,ts) VALUES ('920efc60-45c2-11ee-a631-128faaf8dc1a',0,61,'qualified',35,1370,1,'2023-08-28 16:47:27')
#  INSERT INTO tracking (create_time,bid,campaign_id,custom_track,group_id,job_id,publisher_id,ts) VALUES ('92115b86-45c2-11ee-a823-6b1b459f42a1',0,57,'click',19,1437,2,'2023-08-28 16:47:27')
#  INSERT INTO tracking (create_time,bid,campaign_id,custom_track,group_id,job_id,publisher_id,ts) VALUES ('9213b61a-45c2-11ee-a010-54af42a07820',1,1,'qualified',26,960,23,'2023-08-28 16:47:27')
#  INSERT INTO tracking (create_time,bid,campaign_id,custom_track,group_id,job_id,publisher_id,ts) VALUES ('9215ff4c-45c2-11ee-8422-75f1ef987bf4',0,12,'qualified',16,107,31,'2023-08-28 16:47:27')
#  INSERT INTO tracking (create_time,bid,campaign_id,custom_track,group_id,job_id,publisher_id,ts) VALUES ('921853c8-45c2-11ee-9ec6-892462ce460a',0,61,'conversion',26,1332,9,'2023-08-28 16:47:27')
#  INSERT INTO tracking (create_time,bid,campaign_id,custom_track,group_id,job_id,publisher_id,ts) VALUES ('921ab15e-45c2-11ee-9b74-4339a2a13227',1,61,'click',21,519,1,'2023-08-28 16:47:27')
#  INSERT INTO tracking (create_time,bid,campaign_id,custom_track,group_id,job_id,publisher_id,ts) VALUES ('921d1da4-45c2-11ee-aef6-fe6cf1843185',0,11,'click',10,1056,10,'2023-08-28 16:47:27')
#  INSERT INTO tracking (create_time,bid,campaign_id,custom_track,group_id,job_id,publisher_id,ts) VALUES ('921f903e-45c2-11ee-8f24-dc5b12e4d362',1,57,'click',10,1314,5,'2023-08-28 16:47:27')
#  INSERT INTO tracking (create_time,bid,campaign_id,custom_track,group_id,job_id,publisher_id,ts) VALUES ('92221eb2-45c2-11ee-ba56-10582b52e31f',1,5,'click',10,1956,5,'2023-08-28 16:47:27')
#  INSERT INTO tracking (create_time,bid,campaign_id,custom_track,group_id,job_id,publisher_id,ts) VALUES ('92243206-45c2-11ee-9b59-f987bdae5064',0,10,'click',35,1305,22,'2023-08-28 16:47:27')
#  INSERT INTO tracking (create_time,bid,campaign_id,custom_track,group_id,job_id,publisher_id,ts) VALUES ('9226a842-45c2-11ee-ab4e-ff60603e8832',1,178,'conversion',12,1973,22,'2023-08-28 16:47:27')
#  INSERT INTO tracking (create_time,bid,campaign_id,custom_track,group_id,job_id,publisher_id,ts) VALUES ('9228edc8-45c2-11ee-833c-cfd842a57c51',1,11,'click',10,1381,23,'2023-08-28 16:47:27')
#  INSERT INTO tracking (create_time,bid,campaign_id,custom_track,group_id,job_id,publisher_id,ts) VALUES ('922b62ba-45c2-11ee-bed1-bc42e323f1ce',1,10,'click',41,871,10,'2023-08-28 16:47:27')
# Data Generated Successfully
#  INSERT INTO tracking (create_time,bid,campaign_id,custom_track,group_id,job_id,publisher_id,ts) VALUES ('98282efa-45c2-11ee-9b7e-3dc6637edea5',0,61,'click',35,2020,1,'2023-08-28 16:47:37')
#  INSERT INTO tracking (create_time,bid,campaign_id,custom_track,group_id,job_id,publisher_id,ts) VALUES ('9828e80e-45c2-11ee-b289-43844db32e1a',1,97,'click',35,324,17,'2023-08-28 16:47:37')
#  INSERT INTO tracking (create_time,bid,campaign_id,custom_track,group_id,job_id,publisher_id,ts) VALUES ('982b652a-45c2-11ee-9b1c-2ac9b3b8ea79',1,55,'click',17,1128,1,'2023-08-28 16:47:37')
#  INSERT INTO tracking (create_time,bid,campaign_id,custom_track,group_id,job_id,publisher_id,ts) VALUES ('982daf38-45c2-11ee-bea3-9f2067ddcd67',0,69,'click',15,1592,38,'2023-08-28 16:47:37')
#  INSERT INTO tracking (create_time,bid,campaign_id,custom_track,group_id,job_id,publisher_id,ts) VALUES ('982fd682-45c2-11ee-9907-8e91168f93dc',1,57,'click',41,1981,1,'2023-08-28 16:47:37')
#  INSERT INTO tracking (create_time,bid,campaign_id,custom_track,group_id,job_id,publisher_id,ts) VALUES ('983218fc-45c2-11ee-9aa8-fe87152ad3ea',0,101,'click',10,2052,36,'2023-08-28 16:47:37')
#  INSERT INTO tracking (create_time,bid,campaign_id,custom_track,group_id,job_id,publisher_id,ts) VALUES ('98387986-45c2-11ee-a680-bb21af610204',0,70,'click',28,989,10,'2023-08-28 16:47:37')
#  INSERT INTO tracking (create_time,bid,campaign_id,custom_track,group_id,job_id,publisher_id,ts) VALUES ('98393d30-45c2-11ee-9dc3-322257245566',0,70,'click',41,728,33,'2023-08-28 16:47:37')
#  INSERT INTO tracking (create_time,bid,campaign_id,custom_track,group_id,job_id,publisher_id,ts) VALUES ('983bad86-45c2-11ee-9463-f6d0ff4d345c',1,1,'click',41,1013,29,'2023-08-28 16:47:37')
#  INSERT INTO tracking (create_time,bid,campaign_id,custom_track,group_id,job_id,publisher_id,ts) VALUES ('983deb32-45c2-11ee-bbf7-8e5b74083fae',0,117,'conversion',11,8,38,'2023-08-28 16:47:37')
#  INSERT INTO tracking (create_time,bid,campaign_id,custom_track,group_id,job_id,publisher_id,ts) VALUES ('98405c32-45c2-11ee-9af8-8705a65a4c92',1,142,'qualified',11,1870,10,'2023-08-28 16:47:37')
#  INSERT INTO tracking (create_time,bid,campaign_id,custom_track,group_id,job_id,publisher_id,ts) VALUES ('9842cd46-45c2-11ee-b9b1-2be1e5d7ac4e',1,54,'unqualified',15,551,13,'2023-08-28 16:47:37')
#  INSERT INTO tracking (create_time,bid,campaign_id,custom_track,group_id,job_id,publisher_id,ts) VALUES ('9844f012-45c2-11ee-9ff5-82c1b1310b2f',1,127,'conversion',10,1626,32,'2023-08-28 16:47:37')
#  INSERT INTO tracking (create_time,bid,campaign_id,custom_track,group_id,job_id,publisher_id,ts) VALUES ('98476108-45c2-11ee-99fe-3fea38fa1caa',1,1,'click',10,723,11,'2023-08-28 16:47:37')
#  INSERT INTO tracking (create_time,bid,campaign_id,custom_track,group_id,job_id,publisher_id,ts) VALUES ('984a0728-45c2-11ee-a534-696801779aa0',0,61,'click',10,955,11,'2023-08-28 16:47:37')
# Data Generated Successfully
#  INSERT INTO tracking (create_time,bid,campaign_id,custom_track,group_id,job_id,publisher_id,ts) VALUES ('9e4a8db4-45c2-11ee-a680-60a31a9edb36',1,11,'click',13,233,17,'2023-08-28 16:47:47')
#  INSERT INTO tracking (create_time,bid,campaign_id,custom_track,group_id,job_id,publisher_id,ts) VALUES ('9e4dd60e-45c2-11ee-ba64-e054479667bb',1,1,'click',32,842,10,'2023-08-28 16:47:47')
#  INSERT INTO tracking (create_time,bid,campaign_id,custom_track,group_id,job_id,publisher_id,ts) VALUES ('9e51078e-45c2-11ee-9ae3-4b8be51f5398',0,1,'conversion',11,1387,33,'2023-08-28 16:47:47')
#  INSERT INTO tracking (create_time,bid,campaign_id,custom_track,group_id,job_id,publisher_id,ts) VALUES ('9e53494a-45c2-11ee-a008-8c07b259424f',0,1,'click',25,1251,9,'2023-08-28 16:47:47')
#  INSERT INTO tracking (create_time,bid,campaign_id,custom_track,group_id,job_id,publisher_id,ts) VALUES ('9e55be46-45c2-11ee-8efb-9630a3a127ab',1,12,'click',41,1161,11,'2023-08-28 16:47:47')
#  INSERT INTO tracking (create_time,bid,campaign_id,custom_track,group_id,job_id,publisher_id,ts) VALUES ('9e57cc2c-45c2-11ee-babb-21d77b487b65',1,11,'click',10,1148,17,'2023-08-28 16:47:47')
#  INSERT INTO tracking (create_time,bid,campaign_id,custom_track,group_id,job_id,publisher_id,ts) VALUES ('9e5c14bc-45c2-11ee-b78c-8ade461118a7',0,221,'click',11,1743,13,'2023-08-28 16:47:47')
#  INSERT INTO tracking (create_time,bid,campaign_id,custom_track,group_id,job_id,publisher_id,ts) VALUES ('9e623c7a-45c2-11ee-a2be-97d8be9773bd',1,48,'click',16,1226,3,'2023-08-28 16:47:47')
#  INSERT INTO tracking (create_time,bid,campaign_id,custom_track,group_id,job_id,publisher_id,ts) VALUES ('9e69f442-45c2-11ee-93b7-df7160de519a',1,5,'click',41,1282,15,'2023-08-28 16:47:47')
#  INSERT INTO tracking (create_time,bid,campaign_id,custom_track,group_id,job_id,publisher_id,ts) VALUES ('9e6dcbb2-45c2-11ee-8e4d-aa135859990b',1,1,'conversion',10,1262,30,'2023-08-28 16:47:47')
#  INSERT INTO tracking (create_time,bid,campaign_id,custom_track,group_id,job_id,publisher_id,ts) VALUES ('9e711574-45c2-11ee-91ff-888f6838468c',1,131,'click',24,127,16,'2023-08-28 16:47:47')
#  INSERT INTO tracking (create_time,bid,campaign_id,custom_track,group_id,job_id,publisher_id,ts) VALUES ('9e732f12-45c2-11ee-a607-9721ed73bcff',1,59,'click',32,1963,3,'2023-08-28 16:47:47')
# Data Generated Successfully
#  INSERT INTO tracking (create_time,bid,campaign_id,custom_track,group_id,job_id,publisher_id,ts) VALUES ('a48a7338-45c2-11ee-b4c8-fd1bc9a6cda9',0,48,'click',26,1493,34,'2023-08-28 16:47:58')
#  INSERT INTO tracking (create_time,bid,campaign_id,custom_track,group_id,job_id,publisher_id,ts) VALUES ('a498b75e-45c2-11ee-9819-8e09eee2373e',0,5,'click',13,4,36,'2023-08-28 16:47:58')
#  INSERT INTO tracking (create_time,bid,campaign_id,custom_track,group_id,job_id,publisher_id,ts) VALUES ('a49fa1ae-45c2-11ee-ae99-81d27c44d5ee',1,53,'conversion',35,1142,36,'2023-08-28 16:47:58')
#  INSERT INTO tracking (create_time,bid,campaign_id,custom_track,group_id,job_id,publisher_id,ts) VALUES ('a4a4adfc-45c2-11ee-8c09-256a1319afed',1,15,'qualified',27,237,35,'2023-08-28 16:47:58')
#  INSERT INTO tracking (create_time,bid,campaign_id,custom_track,group_id,job_id,publisher_id,ts) VALUES ('a4ac8950-45c2-11ee-82a8-8ca4a539639b',1,12,'click',26,204,31,'2023-08-28 16:47:58')
#  INSERT INTO tracking (create_time,bid,campaign_id,custom_track,group_id,job_id,publisher_id,ts) VALUES ('a4b03366-45c2-11ee-bec8-ba67b05ae453',1,1,'click',27,618,38,'2023-08-28 16:47:58')
#  INSERT INTO tracking (create_time,bid,campaign_id,custom_track,group_id,job_id,publisher_id,ts) VALUES ('a4b71b90-45c2-11ee-8aa3-e378f83c8184',0,127,'conversion',10,1001,29,'2023-08-28 16:47:58')
#  INSERT INTO tracking (create_time,bid,campaign_id,custom_track,group_id,job_id,publisher_id,ts) VALUES ('a4b990e6-45c2-11ee-9071-36664d694008',1,61,'click',17,878,34,'2023-08-28 16:47:58')
#  INSERT INTO tracking (create_time,bid,campaign_id,custom_track,group_id,job_id,publisher_id,ts) VALUES ('a4bba782-45c2-11ee-869a-7d98885d2ca9',0,57,'unqualified',16,580,9,'2023-08-28 16:47:58')
#  INSERT INTO tracking (create_time,bid,campaign_id,custom_track,group_id,job_id,publisher_id,ts) VALUES ('a4be5842-45c2-11ee-bcea-2f83fc3ffb23',0,53,'click',30,1598,15,'2023-08-28 16:47:58')
#  INSERT INTO tracking (create_time,bid,campaign_id,custom_track,group_id,job_id,publisher_id,ts) VALUES ('a4c5def0-45c2-11ee-8d49-9dbdbbcff13a',1,223,'qualified',32,1275,38,'2023-08-28 16:47:58')
#  INSERT INTO tracking (create_time,bid,campaign_id,custom_track,group_id,job_id,publisher_id,ts) VALUES ('a4ce54fe-45c2-11ee-a874-e0b20e9fc743',0,97,'click',26,1363,10,'2023-08-28 16:47:58')
#  INSERT INTO tracking (create_time,bid,campaign_id,custom_track,group_id,job_id,publisher_id,ts) VALUES ('a4d7fb8a-45c2-11ee-a7c7-11e05ec8b651',1,1,'click',18,1917,27,'2023-08-28 16:47:58')
# Data Generated Successfully
#  INSERT INTO tracking (create_time,bid,campaign_id,custom_track,group_id,job_id,publisher_id,ts) VALUES ('aada4876-45c2-11ee-979c-a11e9eb64674',0,223,'conversion',11,673,22,'2023-08-28 16:48:08')
#  INSERT INTO tracking (create_time,bid,campaign_id,custom_track,group_id,job_id,publisher_id,ts) VALUES ('aadcc3d0-45c2-11ee-b4cc-29d0788f8343',0,11,'click',15,1398,28,'2023-08-28 16:48:08')
#  INSERT INTO tracking (create_time,bid,campaign_id,custom_track,group_id,job_id,publisher_id,ts) VALUES ('aadf9ba0-45c2-11ee-ad9e-7ec92371db5f',1,12,'click',31,1271,38,'2023-08-28 16:48:08')
#  INSERT INTO tracking (create_time,bid,campaign_id,custom_track,group_id,job_id,publisher_id,ts) VALUES ('aae16a5c-45c2-11ee-9549-8b24724ea6bb',0,1,'qualified',10,578,38,'2023-08-28 16:48:08')
#  INSERT INTO tracking (create_time,bid,campaign_id,custom_track,group_id,job_id,publisher_id,ts) VALUES ('aae39dfe-45c2-11ee-a8b5-64303f794f0f',1,61,'qualified',12,1097,2,'2023-08-28 16:48:08')
#  INSERT INTO tracking (create_time,bid,campaign_id,custom_track,group_id,job_id,publisher_id,ts) VALUES ('aae6077e-45c2-11ee-a102-f274cd8634a1',0,12,'qualified',13,2029,33,'2023-08-28 16:48:08')
#  INSERT INTO tracking (create_time,bid,campaign_id,custom_track,group_id,job_id,publisher_id,ts) VALUES ('aae89fca-45c2-11ee-acc7-476edfa95c51',1,1,'click',10,1975,24,'2023-08-28 16:48:08')
#  INSERT INTO tracking (create_time,bid,campaign_id,custom_track,group_id,job_id,publisher_id,ts) VALUES ('aaeafb12-45c2-11ee-9185-b189cc87245c',1,61,'click',32,84,30,'2023-08-28 16:48:08')
#  INSERT INTO tracking (create_time,bid,campaign_id,custom_track,group_id,job_id,publisher_id,ts) VALUES ('aaedad94-45c2-11ee-a262-d264d43cb0df',0,61,'click',26,671,11,'2023-08-28 16:48:08')
#  INSERT INTO tracking (create_time,bid,campaign_id,custom_track,group_id,job_id,publisher_id,ts) VALUES ('aaefd696-45c2-11ee-af33-d38cf5435ce0',0,53,'click',32,655,31,'2023-08-28 16:48:08')
#  INSERT INTO tracking (create_time,bid,campaign_id,custom_track,group_id,job_id,publisher_id,ts) VALUES ('aaf22e5a-45c2-11ee-b086-79248bc71bc8',1,222,'unqualified',19,1000,38,'2023-08-28 16:48:08')
#  INSERT INTO tracking (create_time,bid,campaign_id,custom_track,group_id,job_id,publisher_id,ts) VALUES ('aaf51b56-45c2-11ee-8235-cd93049b2ebb',0,15,'click',35,1021,4,'2023-08-28 16:48:08')
#  INSERT INTO tracking (create_time,bid,campaign_id,custom_track,group_id,job_id,publisher_id,ts) VALUES ('aaf6ac96-45c2-11ee-83ba-c2368f13ba93',1,103,'qualified',11,665,35,'2023-08-28 16:48:08')
#  INSERT INTO tracking (create_time,bid,campaign_id,custom_track,group_id,job_id,publisher_id,ts) VALUES ('aaf913c8-45c2-11ee-a83a-4ff7bc00d0b8',1,1,'click',10,339,24,'2023-08-28 16:48:08')
#  INSERT INTO tracking (create_time,bid,campaign_id,custom_track,group_id,job_id,publisher_id,ts) VALUES ('aafb84aa-45c2-11ee-b562-15b3c30c3624',0,1,'click',17,1102,16,'2023-08-28 16:48:08')
# Data Generated Successfully
#  INSERT INTO tracking (create_time,bid,campaign_id,custom_track,group_id,job_id,publisher_id,ts) VALUES ('b0f89776-45c2-11ee-87df-f202305a3c41',1,9,'click',11,80,11,'2023-08-28 16:48:19')
#  INSERT INTO tracking (create_time,bid,campaign_id,custom_track,group_id,job_id,publisher_id,ts) VALUES ('b0fa1b28-45c2-11ee-8505-11c563b6943c',0,1,'click',10,1543,22,'2023-08-28 16:48:19')
#  INSERT INTO tracking (create_time,bid,campaign_id,custom_track,group_id,job_id,publisher_id,ts) VALUES ('b0fc7256-45c2-11ee-b87a-50696cec9a3e',1,61,'qualified',10,326,5,'2023-08-28 16:48:19')
#  INSERT INTO tracking (create_time,bid,campaign_id,custom_track,group_id,job_id,publisher_id,ts) VALUES ('b0fed4ba-45c2-11ee-85f5-2d9f645efdfa',1,1,'qualified',12,999,12,'2023-08-28 16:48:19')
#  INSERT INTO tracking (create_time,bid,campaign_id,custom_track,group_id,job_id,publisher_id,ts) VALUES ('b1013700-45c2-11ee-b24f-45a3b518afb3',0,1,'click',35,432,37,'2023-08-28 16:48:19')
#  INSERT INTO tracking (create_time,bid,campaign_id,custom_track,group_id,job_id,publisher_id,ts) VALUES ('b1038000-45c2-11ee-bd94-e4c1e5dd2f96',1,61,'conversion',10,1660,4,'2023-08-28 16:48:19')
#  INSERT INTO tracking (create_time,bid,campaign_id,custom_track,group_id,job_id,publisher_id,ts) VALUES ('b1060b9a-45c2-11ee-97b9-c501b5732408',0,9,'click',35,781,13,'2023-08-28 16:48:19')
#  INSERT INTO tracking (create_time,bid,campaign_id,custom_track,group_id,job_id,publisher_id,ts) VALUES ('b108743e-45c2-11ee-add1-d6b2fa459d4c',1,1,'click',19,356,36,'2023-08-28 16:48:19')
#  INSERT INTO tracking (create_time,bid,campaign_id,custom_track,group_id,job_id,publisher_id,ts) VALUES ('b10aed36-45c2-11ee-a9eb-d868b23c12c6',1,79,'unqualified',32,818,11,'2023-08-28 16:48:19')
#  INSERT INTO tracking (create_time,bid,campaign_id,custom_track,group_id,job_id,publisher_id,ts) VALUES ('b10d2df8-45c2-11ee-81cb-4725cb865a08',1,1,'click',10,623,28,'2023-08-28 16:48:19')
# Data Generated Successfully
#  INSERT INTO tracking (create_time,bid,campaign_id,custom_track,group_id,job_id,publisher_id,ts) VALUES ('b70b723c-45c2-11ee-a443-189ce3e5d430',0,61,'qualified',25,120,5,'2023-08-28 16:48:29')
#  INSERT INTO tracking (create_time,bid,campaign_id,custom_track,group_id,job_id,publisher_id,ts) VALUES ('b70ce5d6-45c2-11ee-b20e-f40faa06215c',1,103,'unqualified',11,1188,2,'2023-08-28 16:48:29')
#  INSERT INTO tracking (create_time,bid,campaign_id,custom_track,group_id,job_id,publisher_id,ts) VALUES ('b70f6108-45c2-11ee-a17b-aa728e366507',1,122,'click',14,181,32,'2023-08-28 16:48:29')
#  INSERT INTO tracking (create_time,bid,campaign_id,custom_track,group_id,job_id,publisher_id,ts) VALUES ('b711b174-45c2-11ee-ba62-370630602d0e',1,61,'click',35,729,32,'2023-08-28 16:48:29')
#  INSERT INTO tracking (create_time,bid,campaign_id,custom_track,group_id,job_id,publisher_id,ts) VALUES ('b713ff06-45c2-11ee-a8a6-b53dd9fe2a15',1,57,'click',19,1599,38,'2023-08-28 16:48:29')
# Data Generated Successfully
#  INSERT INTO tracking (create_time,bid,campaign_id,custom_track,group_id,job_id,publisher_id,ts) VALUES ('bd114210-45c2-11ee-ad9f-a532fdaea467',1,51,'click',10,541,3,'2023-08-28 16:48:39')
#  INSERT INTO tracking (create_time,bid,campaign_id,custom_track,group_id,job_id,publisher_id,ts) VALUES ('bd11f200-45c2-11ee-8508-3502cb9dabed',1,223,'click',10,2060,32,'2023-08-28 16:48:39')
#  INSERT INTO tracking (create_time,bid,campaign_id,custom_track,group_id,job_id,publisher_id,ts) VALUES ('bd14653a-45c2-11ee-954e-c06a5e99d7fe',0,57,'unqualified',10,996,24,'2023-08-28 16:48:39')
#  INSERT INTO tracking (create_time,bid,campaign_id,custom_track,group_id,job_id,publisher_id,ts) VALUES ('bd168be4-45c2-11ee-92cb-861de8fe80cd',1,122,'click',32,1632,23,'2023-08-28 16:48:39')
#  INSERT INTO tracking (create_time,bid,campaign_id,custom_track,group_id,job_id,publisher_id,ts) VALUES ('bd192eb2-45c2-11ee-8c2a-497bdb900658',1,1,'click',15,120,31,'2023-08-28 16:48:39')
# Data Generated Successfully
#  INSERT INTO tracking (create_time,bid,campaign_id,custom_track,group_id,job_id,publisher_id,ts) VALUES ('c322604e-45c2-11ee-8399-acc4f9ec62d8',1,48,'click',21,1916,13,'2023-08-28 16:48:49')
#  INSERT INTO tracking (create_time,bid,campaign_id,custom_track,group_id,job_id,publisher_id,ts) VALUES ('c32969ac-45c2-11ee-8aff-b213b55964b8',0,100,'qualified',16,1397,3,'2023-08-28 16:48:49')
#  INSERT INTO tracking (create_time,bid,campaign_id,custom_track,group_id,job_id,publisher_id,ts) VALUES ('c32d155c-45c2-11ee-bdc2-b50a788d0ad6',1,101,'conversion',13,1128,28,'2023-08-28 16:48:49')
#  INSERT INTO tracking (create_time,bid,campaign_id,custom_track,group_id,job_id,publisher_id,ts) VALUES ('c3345ed4-45c2-11ee-8d8d-053ff5ed47e3',0,70,'click',41,1771,20,'2023-08-28 16:48:49')
#  INSERT INTO tracking (create_time,bid,campaign_id,custom_track,group_id,job_id,publisher_id,ts) VALUES ('c3394304-45c2-11ee-931c-6c09189e1b54',1,59,'qualified',10,1335,9,'2023-08-28 16:48:49')
# Data Generated Successfully
#  INSERT INTO tracking (create_time,bid,campaign_id,custom_track,group_id,job_id,publisher_id,ts) VALUES ('c937bc68-45c2-11ee-94c0-fb134d9a766d',0,1,'conversion',10,2026,9,'2023-08-28 16:48:59')
#  INSERT INTO tracking (create_time,bid,campaign_id,custom_track,group_id,job_id,publisher_id,ts) VALUES ('c938cdc4-45c2-11ee-a16c-c890d10cae44',0,221,'unqualified',17,2026,31,'2023-08-28 16:48:59')
#  INSERT INTO tracking (create_time,bid,campaign_id,custom_track,group_id,job_id,publisher_id,ts) VALUES ('c93b5f26-45c2-11ee-bff3-8173070759e7',1,101,'click',12,879,17,'2023-08-28 16:48:59')
#  INSERT INTO tracking (create_time,bid,campaign_id,custom_track,group_id,job_id,publisher_id,ts) VALUES ('c93d821a-45c2-11ee-9484-1be26ff42440',1,221,'click',32,561,28,'2023-08-28 16:48:59')
#  INSERT INTO tracking (create_time,bid,campaign_id,custom_track,group_id,job_id,publisher_id,ts) VALUES ('c94001b6-45c2-11ee-82ac-3a018165e2ae',0,12,'qualified',26,480,31,'2023-08-28 16:48:59')
#  INSERT INTO tracking (create_time,bid,campaign_id,custom_track,group_id,job_id,publisher_id,ts) VALUES ('c94259f2-45c2-11ee-91f4-0e2efb494bae',0,61,'click',17,1434,36,'2023-08-28 16:48:59')
#  INSERT INTO tracking (create_time,bid,campaign_id,custom_track,group_id,job_id,publisher_id,ts) VALUES ('c944d16e-45c2-11ee-b94c-73978b484c67',0,131,'qualified',21,199,13,'2023-08-28 16:48:59')
#  INSERT INTO tracking (create_time,bid,campaign_id,custom_track,group_id,job_id,publisher_id,ts) VALUES ('c94712bc-45c2-11ee-939d-878ef9a0d185',0,63,'click',41,785,20,'2023-08-28 16:48:59')
#  INSERT INTO tracking (create_time,bid,campaign_id,custom_track,group_id,job_id,publisher_id,ts) VALUES ('c9496fc6-45c2-11ee-817b-1c2678ede795',0,131,'click',16,697,29,'2023-08-28 16:48:59')
#  INSERT INTO tracking (create_time,bid,campaign_id,custom_track,group_id,job_id,publisher_id,ts) VALUES ('c94bfd54-45c2-11ee-9503-935299e00a71',0,1,'conversion',10,289,31,'2023-08-28 16:48:59')
#  INSERT INTO tracking (create_time,bid,campaign_id,custom_track,group_id,job_id,publisher_id,ts) VALUES ('c94e6a08-45c2-11ee-b671-74024bd2dca5',0,90,'click',26,1862,9,'2023-08-28 16:48:59')
# Data Generated Successfully
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# d:\data_engineer\FAKING_DATA_SCRIPT.ipynb Cell 7 in 4
#       <a href='vscode-notebook-cell:/d%3A/data_engineer/FAKING_DATA_SCRIPT.ipynb#W6sZmlsZQ%3D%3D?line=1'>2</a> while status == "ON":
#       <a href='vscode-notebook-cell:/d%3A/data_engineer/FAKING_DATA_SCRIPT.ipynb#W6sZmlsZQ%3D%3D?line=2'>3</a>     generating_dummy_data(n_records = random.randint(1,20),session = session , user = user , password = password , host = host , db_name = db_name )
# ----> <a href='vscode-notebook-cell:/d%3A/data_engineer/FAKING_DATA_SCRIPT.ipynb#W6sZmlsZQ%3D%3D?line=3'>4</a>     time.sleep(10)
#
# KeyboardInterrupt:
